# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scikit as sk

# %% [markdown]
# ### Loading CSV

# %%
df = pd.read_csv("ai4i2020.csv")
